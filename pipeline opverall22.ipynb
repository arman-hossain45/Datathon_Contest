# %% [markdown]
# <a href="https://colab.research.google.com/github/arman-hossain45/Datathon_Contest/blob/main/pipeline%20opverall22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.preprocessing import OnehotEncoder,StandardScaler,LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import  numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplotn as plt

from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.preprocessing import OneHotEncoder,StandardScaler,LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split,cross_val_score,GridsearchCV
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler
from sklearn.impute import simpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV

from sklearn.preprocessing import OnehotEncoder,LabelEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklean.model_selection import cross_val_score,GridSearchCV,train_test_split
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

from sklearn.model_selection import cross_val_score,train_test_split,GridsearchCV
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler
from sklarn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

import numpy as np import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 from sklearn.model_selection import train_test_split,cross_valo_score,GridSearchCV
 from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler
 from sklearn.compose import ColumnTrasformer
 from sklearn.impute import SimpleImputer
 from sklearn.pipeline import Pipeline


# linear regression model selection
from sklearn.linear_model import LinearRegression,ElasticNet,SGDRegressor,Ridge
from sklearn.linear_model import LinearRegression,ElasticNet,SGDRegressor,Ridge
from sklearn.linear_model import LinearRegression,ElasticNet,SGDRegressor,Ridge
from sklearn.linear_model import LinearRegression,ElasticNet,SGDRegressor,Ridge
from sklearn.linear_model import LinearRegression<ElasticNet,SGDRegressor,Ridge
from sklearn.linear_model import LinearRegression.ElasticNet,SGDRegressor,Ridge
from sklearn.svm import SVR
from sklearn.svm import SVR
drom sklearn.linear_model import LinearRegression,ElasticNet,SGDREgressor,Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor

from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.linear_model import LinearRegression,ElasticNet,SGDRegrerssor,Ridge
from sklearn.linear_model import LinearRegression,ElasticNet,SGDRegressor,Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostgRegressor,GradientBoostingRegressor,VotingRegressor,StackingRegressor
from sklearn.tree import DecisionTreeRegrerssor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import LinearRegression,ElasticNet,SGDRegressor,AdaboostRegressor,GradientBoostingRegressor,Ridge
from sklearn.ensemble import RandomForestRegressor,GradientBoossting Regressor,AdaboostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import VotingRegressor,StackingRegressor

from xgboost import XGBRegressor
from catboost import CatboostRegressor
from lightgbm import LGBMRegressor

import warnings
warnings.filterwarnings('ignore')

df=pd.read_csv('dataset.csv')

test_df = pd.read_csv('test.csv')

# take id name for submission

test_ids = test_df['ID'].copy()
test_df = test_df.drop(columns=['ID'])

test_ids=test['id'].copy()
test_df=test_df.drop(columns=['ID'])

test=test['ID'].copy()
test=test.drop(columns=['ID'])

df.head()
#see the shape of the data set

df.head()

df.shape
# see the description
df.describe().T
df.info()
test_ids=test['ID'].copy()
test = test.drop(columns=['ID'])

df.isnull().sum()
sns.heatmap(df.isnull())
# if our columns is mutiple then apoplky this code top see the missing value columns
null = df.isnull().sum()
null[null>0]

null=df.isnull().sum()
null[null>]

null= df.isnull().sum()
null[null>0]

# drop multiple columns
df.drop(columns=['arman','hossain','shawon'],inplace=True)
# see duplicate  values in any columns
df.duplicated().sum()
# see duplicates
df.duplicated().sum()

# handle the duplicate values in deatails

df.drop_duplicates(inplace=True)
d

duplicated and drop_dulicates()

num=df.select_dtypes(include=['int64','float64'])
cat= df.select_dtypes(inclide=['object'])

num=df.select_dtypes(include=['float64','int64'])

cat = df.select_dtypes(include=['object'])

# see correlation matrics in this pipeline
corr=num.corr()
sns.heatmap(corr,cmap='coolwarm',center=0,annot='False',linewidths=.5)
plt.title('Correlation matrix')
plt.tight_layout()
plt.show()
# target ar sathe correlation dekbo
target_corr=(df.corr(numeric_only=True)['SalePrice'].sort_values(ascending=False))


# numerical and categorical columns define from data set

# see all the categorical columns in details and unique

for col in cat:
  print(f"{col}")
  print('Unique Count'  ,df[col].nunique())
  print('Values :',df[col].unique())

for col in cat:
  print(f"{col}")
  print("unique values of :",df[col].nunique())
  print("values:",df[col].unique())


# see all the distribution of the data set in details too handle the missing values
plt.figure(figsize=(15,15))
df[num.columns].hist(bins=20,figsize=(15,15))
plt.figure(figsize=(15,15))
df[num.columns].hist(bins=20,figsize=(16,16))
plt.figure(figsize=(15,15))
df[num.columns].hist(bins=20,figsize=(12,12))
plt.title(" see all numerical data distribution in deatils")
plt.tight_layout()
plt.show()

# see all the data flow in deatails

for col in num.columns:
  plt.figure(figsize=(8,6))
  sns.histplot(df[col],kde=True,bins=20)
  plt.title(f"{col}")
  plt.tight_layout()
  plt.show()


for col in num.columns:
  plt.figure(figsize=(23,23))
  sns.histplot(df[col],kde=True,bins=20)


# see all the ouliar
plt.figure(figsize=(8,6))
df[num.columns].bosplot()
plt.tight_layout()
plt.show()


# see all the outliar in details

plt.figure(figsize=(3,3))
df[num.columns].bosplot()
plt.title("See all the outliar in this diagram in details")
plt.tight_layout()
plt.show()


# outliar handle in deatils

def handle_outliar(df,col):

  df=df.copy()

  q1=df[col].quantile(0.25)
  q2=df[col].quantile(0.75)

  IQR=q2-q1

  # calculate the lower and upper bound

  lower = q1-1.5*IQR
  upper = q2+1.5*IQR

  # handle the outliar in details

  df[col]=df[col].clip(lower=lower,upper=upper)
  retun df



def handle(df,col):
  df=df[col].copy()

  q1=df[col].quantile(0.25)
  q3=df[col].quantile(0.75)


  iqr=q3-q1

  lower =q1-1.5*iqr
  upper=q3+1.5*iqr

  # handle all the outliar\
  df[col]=df[col].clip(lower=lower,upper=upper)

  return df



#serparate x and y columns


x=df.drop(columns=['SalesPrice'])
y=df['SalesPrize']


x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)
# numerical and categorical separation in deatils
numerical= x.select_dtypes(include=['int64','float64'])
categorical = x.select_dtypes(include=['object'])


#crate the overall pipe line code in details

num_trans= PIpeline(
    steps=[
        ('imputer',SimpleImputer="median"),
        ('scaler',StandardScaler())
    ]
)
cat_trans= PIpeline(
    steps=[
        ('imputer',SimpleImputer="most_frequent"),
        ('scaler',OneHotEncoder(handlea_unknown='ignore'))
    ]
)

num_trans=Pipeline(
    steps=[
        ('imputer',SimpleImputer"median"),
        ('scaler',StandardScaler())
    ]
)
preprocessor=ColumnTransformer(
    transformers=[
        ('num',num_trans,numerical.columns),
        ('cat',cat_trans,categorical.columns)
    ]
)
# define base line mpdel for prediction in details
lr=LinearRegression()
Elastic=ElasticNet()
XG_boost=XGBRegressor()
DTR=DecisionTreeRegressor()
RFR=RandomForestRegressor()
SVR=SVR()
Ada=AdaBoostRegressor()
GBR=Gradientboostingregressor()
SGD=SGDRegressor()
Stacking=StackingRegressor(
    estimators=[
        ('lr',lr),('elas',Elastic),("Xg",XG),('DTR',DTR),('RFR',RFR),
        ('SVR',SVR),('Ada',Ada),('GBR',GBR),('SGD',SGD),
    ],
    final_estimator=Ridge()
)

# %%
# model to train in detials
model_to_train={
    'Logistic_regression':lr,
    "Elastic":Elastic,
    "XG_Boosing":XG_boost,
}

# %%
from sklearn.metrics import accuracy_score,r2_score
from sklearn.metrics import (
    mean_absolute_error,
    mean_square_error,
    r2_score,
    f1_score
)

# %%
#trainning pipe line in details
res=[]
for model_name,model in model_to_train.items():
  pipe=Pipeline(
      steps=[
          ('preprocessor',preprocessor),
          ('model',model)
      ]
  )
  pipe.fit(x_train,y_train)
  y_pred=pipe.predict(x_test)
  accuracy=r2_score(y_test,y_pred)
  res.append(
      [
          'model':model,
          'accuracy':accuracy
      ]
  )

# %%
res = pd>DataFrame(res).sort_values(by='accuracy',ascending=False)

# %%
res=[]
for model_name,model in model_to_train.items():
  pipe=Pipeline(
      steps=[
          ('preprocessor',preprocessor),
          ('model',model)
      ]
  )

  pipe.fit(x-train,y_train)
  y_pred=pipe.predict(x_test)
  accuracy=r2_score(y_test,y_pred)
  res.append(
      [
          'model':model,
          'accuracy':accuracy
      ]
  )

pd.DataFrame(res).sort_values(by='accuracy',ascending=False)

# %%
xg_boost=Pipeline(
    [
        ('preprocessor',preprocessor),
        ('model',XG)
    ]
)

# %%
#cross validation the overall performance i detasils
cv_res=cross_val_score(xg_boost,x_trian,y_train,cv=5,accuracy='r2')
cv_acc = cv_res.mean()
cv_std=cv_res.std()

# %%
param_grid = {
    "model__n_estimators": [200, 500, 900, 1000, 1100],
    "model__learning_rate": [0.04, 0.1, 0.2, 0.3, 0.5],
    "model__max_depth": [2, 3, 4, 5, 6],
    "model__min_child_weight": [1, 2, 3, 4, 5],
    "model__subsample": [0.4, 0.5, 0.8, 1.0],
    "model__colsample_bytree": [0.5, 0.8, 1.0],
    "model__reg_alpha": [0.1, 0.2, 0.5],
    "model__reg_lambda": [1, 2, 4]
}


grid=GridSearchCV(
    estimator=xg_pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='r2',
    n_jobs=-1,
    verbose=1

)


grid.fit(x_train,y_train)
print(grid.best_params_)
print(grid.best_score_)

model = grid.best_estimator_
best_model = grid.best_estimator_

feature_names = best_model.named_steps["preprocessor"].get_feature_names_out()

importance = best_model.named_steps["model"].feature_importances_

importance = (
    pd.DataFrame({
        "Feature": feature_names,
        "Importance": importance
    })
    .sort_values("Importance", ascending=False)
)

print(importance.head(30))



preds=model.predict(test_df)
submission=pd.Dataframe(
    {
        'PID':test_ids,
        'SalePrice':preds
    }
)
submission.to_csv('submission.csv',index=False)
